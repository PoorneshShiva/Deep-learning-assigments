# %% [markdown]
# <a href="https://colab.research.google.com/github/PoorneshShiva/Deep-learning-assigments/blob/main/03_FashionMNIST_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Challenge: Get the best results on the [fashion-MNIST](https://github.com/zalandoresearch/fashion-mnist) dataset!
#
# > "Fashion-MNIST is a dataset of Zalando's article images—consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes. We intend Fashion-MNIST to serve as a direct drop-in replacement for the original MNIST dataset for benchmarking machine learning algorithms. It shares the same image size and structure of training and testing splits."
#
# <img src="https://raw.githubusercontent.com/zalandoresearch/fashion-mnist/master/doc/img/fashion-mnist-sprite.png">
#
#
# TASK - Challenge: Get the best results on the fashionMNIST dataset!
#
# The challenge of this task is to get the best results on the fashionMNIST dataset by tuning hyperparameters of the model and observing convergence behavior.
#
# "Best" - for simplicity - means the highest accuracy on the validation set.
#
# "Rules":
#
#     You can change any hyperparameters,
#     including the number of layers,
#     width of the layers,
#     activation functions,
#     regularizers (and their parameters),
#     optimizer (and it's parameters), but
#     you should not change the model architecture, use only fully connected layers! (Even if you know any others... :-P
#
# Added constraint: The model with the "best performance" has to be saved, so it should not be just a printout happening once during training!
#
# And: You may NOT manipulate the validation set! :-P
#
# Happy coding! :-)

# %% [markdown]
# # Loading the data

# %%
import tensorflow as tf

(train_images, train_labels), (valid_test_images, valid_test_labels) = tf.keras.datasets.fashion_mnist.load_data()

# because of some limitations of Keras's softmax implementation, it's
# advisable to normalise the images by dividing the intensities by the
# maximal 255 value
train_images = train_images / 255.

valid_test_images = valid_test_images / 255. # the same normalization for valid and test

valid_images = valid_test_images[:5000]
valid_labels = valid_test_labels[:5000]
test_images = valid_test_images[5000:]
test_labels = valid_test_labels[5000:]

print(train_images.shape, valid_images.shape, test_images.shape)
# Out:
# (60000, 28, 28) (5000, 28, 28) (5000, 28, 28)

# %% [markdown]
# The classes are:
# 0.   T-shirt/top
# 1.   Trouser
# 2.	Pullover
# 3.	Dress
# 4.	Coat
# 5.	Sandal
# 6.	Shirt
# 7.	Sneaker
# 8.	Bag
# 9.	Ankle boot

# %%
classes = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# Let's have a look at the first few training images:

# %%
from matplotlib import pyplot as plt
from math import ceil

def show_images(images, labels):
    """Show images in a grid
    """
    n_rows = ceil(len(images) / 10)
    plt.figure(figsize=(20, 8))
    for i, image in enumerate(images):
        ax = plt.subplot(n_rows, 10, i + 1, xticks=[], yticks=[])
        # below we scale the pixel intensities back to display the images correctly
        plt.imshow(image, cmap='Greys')
        plt.title(classes[labels[i]])

show_images(train_images[:30], train_labels[:30])
plt.show();

# %% [markdown]
# Transform images with size of 22x22 to array of 784, so it can be used as input of the network

# %%
def reshape(images):
    images = images.reshape(images.shape[0], -1)
    return images

train_images = reshape(train_images)
valid_images = reshape(valid_images)
test_images = reshape(test_images)

print(train_images.shape, valid_images.shape, test_images.shape)
# Out:
# (60000, 784) (5000, 784) (5000, 784)

# %% [markdown]
# # Model

# %% [markdown]
# We set the random seeds to get (as far as possible) reproducible results:

# %%
# Fix seeds for (hopefully) reproducible results
from numpy.random import seed
import tensorflow as tf

seed(14)
tf.random.set_seed(19)

# %% [markdown]
# ## Network

# %%
# TODO: Try different models with different number of hidden layer
from keras.models import Sequential
from keras.layers import Dense, Input

model = Sequential()

model.add(Input(shape=(784,)))
model.add(Dense(units=256, activation='relu'))

model.add(Dense(units=10, activation="softmax"))

# %% [markdown]
# ## Loss, optimization and compilation

# %%
from tensorflow.keras.optimizers import Adadelta, Adam
from tensorflow.keras.losses import sparse_categorical_crossentropy

# Loss
loss = sparse_categorical_crossentropy # we use this cross entropy variant as the input is not
                                       # one-hot encoded

# Optimizer
optimizer = Adam() # A "smart" SGD variant

# Compilation
#############
model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

# %% [markdown]
# ## Training

# %%
# TODO: Train the model
model.fit(train_images, train_labels)
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7865 - loss: 0.6019

# %%
# TODO: Train the model
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8660 - loss: 0.3700
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8817 - loss: 0.3255
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8907 - loss: 0.2964
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8989 - loss: 0.2752
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.9044 - loss: 0.2587
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9092 - loss: 0.2439
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9125 - loss: 0.2326
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9179 - loss: 0.2210
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9216 - loss: 0.2121
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9239 - loss: 0.2031

# %%
# TODO: Train the model
model.fit(train_images, train_labels, epochs=10, batch_size=50 )
# Out:
# Epoch 1/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9288 - loss: 0.1879
# Epoch 2/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9319 - loss: 0.1806
# Epoch 3/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9349 - loss: 0.1748
# Epoch 4/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9374 - loss: 0.1666
# Epoch 5/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9399 - loss: 0.1623
# Epoch 6/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9421 - loss: 0.1554
# Epoch 7/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9447 - loss: 0.1499
# Epoch 8/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9455 - loss: 0.1461
# Epoch 9/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9478 - loss: 0.1396
# Epoch 10/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9494 - loss: 0.1354

# %%
# Loss
loss = sparse_categorical_crossentropy # we use this cross entropy variant as the input is not
                                       # one-hot encoded

# Optimizer
# optimizer = Adam() # A "smart" SGD variant
optimizer=tf.keras.optimizers.SGD(learning_rate=0.01)
# Compilation
#############
model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

# %%
# TODO: Train the model
model.fit(train_images, train_labels, epochs=10, batch_size=50 )
# Out:
# Epoch 1/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9617 - loss: 0.1073
# Epoch 2/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9619 - loss: 0.1066
# Epoch 3/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9619 - loss: 0.1061
# Epoch 4/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9622 - loss: 0.1057
# Epoch 5/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9624 - loss: 0.1053
# Epoch 6/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9626 - loss: 0.1049
# Epoch 7/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9626 - loss: 0.1046
# Epoch 8/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9627 - loss: 0.1042
# Epoch 9/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9628 - loss: 0.1039
# Epoch 10/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9628 - loss: 0.1035

# %%
# Loss
loss = sparse_categorical_crossentropy # we use this cross entropy variant as the input is not
                                       # one-hot encoded

# Optimizer
# optimizer = Adam() # A "smart" SGD variant
optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.09)
# Compilation
#############
model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

# %%
# TODO: Train the model
history = model.fit(train_images, train_labels, epochs=10, batch_size=50, validation_split=0.2)
# Out:
# Epoch 1/10
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9645 - loss: 0.0992 - val_accuracy: 0.9628 - val_loss: 0.1008
# Epoch 2/10
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9647 - loss: 0.0988 - val_accuracy: 0.9626 - val_loss: 0.1014
# Epoch 3/10
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9651 - loss: 0.0984 - val_accuracy: 0.9622 - val_loss: 0.1019
# Epoch 4/10
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9650 - loss: 0.0981 - val_accuracy: 0.9619 - val_loss: 0.1024
# Epoch 5/10
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9653 - loss: 0.0977 - val_accuracy: 0.9617 - val_loss: 0.1027
# Epoch 6/10
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9655 - loss: 0.0974 - val_accuracy: 0.9614 - val_loss: 0.1031
# Epoch 7/10
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9655 - loss: 0.0971 - val_accuracy: 0.9613 - val_loss: 0.1034
# Epoch 8/10
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9656 - loss: 0.0967 - val_accuracy: 0.9612 - val_loss: 0.1037
# Epoch 9/10
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9658 - loss: 0.0964 - val_accuracy: 0.9610 - val_loss: 0.1040
# Epoch 10/10
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9659 - loss: 0.0961 - val_accuracy: 0.9608 - val_loss: 0.1042

# %% [markdown]
# ## Training Performance

# %%
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Quality Check

# %%
assert max(history.history['accuracy'])>0.72
assert max(history.history['val_accuracy'])>0.73

# %% [markdown]
# ## Visualization

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Predict
predictions = model.predict(test_images)

# Create confusion matrix and normalizes it over predicted (columns)
cm = confusion_matrix(test_labels, predictions.argmax(axis=1))

# Plot
cmd = ConfusionMatrixDisplay(cm, display_labels=classes)
fig, ax = plt.subplots(figsize=(10,10))
cmd.plot(ax=ax)
# Out:
# 157/157 [==============================] - 1s 6ms/step

# %%
from sklearn.metrics import classification_report

print(classification_report(test_labels, predictions.argmax(axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83       493
#            1       0.98      0.97      0.97       519
#            2       0.84      0.75      0.79       479
#            3       0.87      0.91      0.89       500
#            4       0.79      0.81      0.80       479
#            5       0.96      0.94      0.95       515
#            6       0.69      0.67      0.68       518
#            7       0.95      0.92      0.93       500
#            8       0.99      0.97      0.98       474
#            9       0.92      0.97      0.95       523
#
#     accuracy                           0.88      5000
#    macro avg       0.88      0.88      0.88      5000
# weighted avg       0.88      0.88      0.88      5000

# %% [markdown]
# ## Saving the model

# %%
model.save('my_model.h5')  # creates a HDF5 file 'my_model.h5'
