# %% [markdown]
# # Layers Exploration

# %%
import tensorflow as tf

# Check TensorFlow version
print(f"TensorFlow version: {tf.__version__}")

# List available physical devices
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    print(f"GPUs available: {len(physical_devices)}")
    for i, gpu in enumerate(physical_devices):
        print(f"GPU {i}: {gpu}")
else:
    print("No GPUs detected.")

# Check if TensorFlow is using GPU
gpu_device_name = tf.test.gpu_device_name()
if gpu_device_name:
    print(f"Default GPU device: {gpu_device_name}")
else:
    print("TensorFlow is not using the GPU.")
# Out:
# TensorFlow version: 2.10.1
# GPUs available: 1
# GPU 0: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Default GPU device: /device:GPU:0

# %%
import numpy as np
import os

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, Conv2D, MaxPool2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adadelta, Adam, SGD
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.regularizers import l1
from tensorflow.keras.backend import clear_session
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.initializers import glorot_normal

# Fix seeds for (hopefully) reproducible results
from numpy.random import seed
seed(14)
tf.random.set_seed(19)

# %%
train, test = tf.keras.datasets.cifar10.load_data()

# TODO: Split the images into different sets and normalise them
train_images = train[0]  / 255.
train_labels = train[1]
test_images = test[0]  / 255.
test_labels = test[1]

print(train_images.shape, test_images.shape)
print(train_labels.shape, test_labels.shape)
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# (50000, 1) (10000, 1)

# %%
from tensorflow.keras.layers import Conv2D, InputLayer, MaxPool2D, SpatialDropout2D, Activation,Dropout
from tensorflow.keras import Sequential

# %%
model = Sequential(
    [
    InputLayer((32,32, 3)),
    Conv2D(32,1, padding='same'),
    MaxPool2D(2, 2, padding='valid'),
    SpatialDropout2D(0.2),

    
    Conv2D(32,1, padding='same'),
    MaxPool2D(2, 2, padding='valid'),
    SpatialDropout2D(0.2),
    
    Conv2D(32,1, padding='same'),
    MaxPool2D(2, 2, padding='valid'),
    SpatialDropout2D(0.2),

        
    Conv2D(32,1, padding='same'),
    MaxPool2D(2, 2, padding='valid'),
    SpatialDropout2D(0.2),

    Dense(264, "relu"),
    Dropout(0.1),
    Dense(128, "relu"),
    Dropout(0.2),
    Dense(10, activation='softmax'),
        
        
    ]
        )


from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# spatial_dropout2d_4 (Spatial (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 32)        1056
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# spatial_dropout2d_5 (Spatial (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 32)          1056
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 4, 4, 32)          0
# _________________________________________________________________
# spatial_dropout2d_6 (Spatial (None, 4, 4, 32)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 32)          1056
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 2, 2, 32)          0
# _________________________________________________________________
# spatial_dropout2d_7 (Spatial (None, 2, 2, 32)          0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2, 2, 264)         8712
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 2, 264)         0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2, 2, 128)         33920
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 128)         0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2, 2, 10)          1290
# =================================================================
# Total params: 47,218
# Trainable params: 47,218
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# model.fit(x=train_images, y=train_labels, validation_data=(test_images, test_labels), epochs=20, batch_size=32)
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=32
)


from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[15], line 2
#       1 # model.fit(x=train_images, y=train_labels, validation_data=(test_images, test_labels), epochs=20, batch_size=32)
# ----> 2 history = model.fit(
#       3     x=train_images,
#       4     y=train_labels,
#       5     validation_data=(test_images, test_labels),
#       6     epochs=20,
#       7     batch_size=32
#       8 )
#      11 from matplotlib import pyplot as plt
#      12 # TODO: Plot loss and accuracy
#
# File A:\Anaconda\envs\tf-gpu\lib\site-packages\tensorflow\python\keras\engine\training.py:1193, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1186 with trace.Trace(
#    1187     'train',
#    1188     epoch_num=epoch,
#    1189     step_num=step,
#    1190     batch_size=batch_size,
#    1191     _r=1):
#    1192   callbacks.on_train_batch_begin(step)
# -> 1193   tmp_logs = self.train_function(iterator)
#    1194   if data_handler.should_sync:
#    1195     context.async_wait()
#
# File A:\Anaconda\envs\tf-gpu\lib\site-packages\tensorflow\python\eager\def_function.py:885, in Function.__call__(self, *args, **kwds)
#     882 compiler = "xla" if self._jit_compile else "nonXla"
#     884 with OptionalXlaContext(self._jit_compile):
# --> 885   result = self._call(*args, **kwds)
#     887 new_tracing_count = self.experimental_get_tracing_count()
#     888 without_tracing = (tracing_count == new_tracing_count)
#
# File A:\Anaconda\envs\tf-gpu\lib\site-packages\tensorflow\python\eager\def_function.py:950, in Function._call(self, *args, **kwds)
#     946     pass  # Fall through to cond-based initialization.
#     947   else:
#     948     # Lifting succeeded, so variables are initialized and we can run the
#     949     # stateless function.
# --> 950     return self._stateless_fn(*args, **kwds)
#     951 else:
#     952   _, _, _, filtered_flat_args = \
#     953       self._stateful_fn._function_spec.canonicalize_function_inputs(  # pylint: disable=protected-access
#     954           *args, **kwds)
#
# File A:\Anaconda\envs\tf-gpu\lib\site-packages\tensorflow\python\eager\function.py:3039, in Function.__call__(self, *args, **kwargs)
#    3036 with self._lock:
#    3037   (graph_function,
#    3038    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3039 return graph_function._call_flat(
#    3040     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File A:\Anaconda\envs\tf-gpu\lib\site-packages\tensorflow\python\eager\function.py:1963, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1959 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1960 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1961     and executing_eagerly):
#    1962   # No tape is watching; skip to running the function.
# -> 1963   return self._build_call_outputs(self._inference_function.call(
#    1964       ctx, args, cancellation_manager=cancellation_manager))
#    1965 forward_backward = self._select_forward_and_backward_functions(
#    1966     args,
#    1967     possible_gradient_type,
#    1968     executing_eagerly)
#    1969 forward_function, args_with_tangents = forward_backward.forward()
#
# File A:\Anaconda\envs\tf-gpu\lib\site-packages\tensorflow\python\eager\function.py:591, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     589 with _InterpolateFunctionError(self):
#     590   if cancellation_manager is None:
# --> 591     outputs = execute.execute(
#     592         str(self.signature.name),
#     593         num_outputs=self._num_outputs,
#     594         inputs=args,
#     595         attrs=attrs,
#     596         ctx=ctx)
#     597   else:
#     598     outputs = execute.execute_with_cancellation(
#     599         str(self.signature.name),
#     600         num_outputs=self._num_outputs,
#    (...)
#     603         ctx=ctx,
#     604         cancellation_manager=cancellation_manager)
#
# File A:\Anaconda\envs\tf-gpu\lib\site-packages\tensorflow\python\eager\execute.py:59, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57 try:
#      58   ctx.ensure_initialized()
# ---> 59   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                       inputs, attrs, num_outputs)
#      61 except core._NotOkStatusException as e:
#      62   if name is not None:
#
# InvalidArgumentError:  required broadcastable shapes
# 	 [[node Equal (defined at C:\Users\Poorn\AppData\Local\Temp\ipykernel_16084\1447636784.py:2) ]] [Op:__inference_train_function_41965]
#
# Function call stack:
# train_function

# %%
model = Sequential(
    [
    InputLayer((32,32, 3)),
    Conv2D(32,1, padding='same'),
    MaxPool2D(2, 2, padding='valid'),
    SpatialDropout2D(0.2),

    
    Conv2D(64,1, padding='same'),
    MaxPool2D(2, 2, padding='valid'),
    SpatialDropout2D(0.2),
    
    Conv2D(128,1, padding='same'),
    MaxPool2D(2, 2, padding='valid'),
    SpatialDropout2D(0.2),

        
    Conv2D(32,1, padding='same'),
    MaxPool2D(2, 2, padding='valid'),
    SpatialDropout2D(0.2),
    Flatten(),
    Dense(512, "relu"),
    Dropout(0.1),
    Dense(10, activation='softmax'),
        
        
    ]
        )
model.summary()
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=32
)


from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# spatial_dropout2d_8 (Spatial (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 16, 16, 64)        2112
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# spatial_dropout2d_9 (Spatial (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 8, 8, 128)         8320
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# spatial_dropout2d_10 (Spatia (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 4, 4, 32)          4128
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 2, 2, 32)          0
# _________________________________________________________________
# spatial_dropout2d_11 (Spatia (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               66048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 85,866
# Trainable params: 85,866
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1563/1563 [==============================] - 19s 11ms/step - loss: 1.8141 - accuracy: 0.3415 - val_loss: 1.6443 - val_accuracy: 0.4075
# Epoch 2/20
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.6639 - accuracy: 0.4062 - val_loss: 1.5241 - val_accuracy: 0.4538
# Epoch 3/20
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.6192 - accuracy: 0.4224 - val_loss: 1.4873 - val_accuracy: 0.4761
# Epoch 4/20
# 1563/1563 [==============================] - 16s 10ms/step - loss: 1.5897 - accuracy: 0.4370 - val_loss: 1.4742 - val_accuracy: 0.4794
# Epoch 5/20
# 1563/1563 [==============================] - 23s 14ms/step - loss: 1.5657 - accuracy: 0.4430 - val_loss: 1.4594 - val_accuracy: 0.4913
# Epoch 6/20
# 1563/1563 [==============================] - 24s 16ms/step - loss: 1.5549 - accuracy: 0.4465 - val_loss: 1.4383 - val_accuracy: 0.4880
# Epoch 7/20
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.5389 - accuracy: 0.4545 - val_loss: 1.4170 - val_accuracy: 0.5007
# Epoch 8/20
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.5223 - accuracy: 0.4626 - val_loss: 1.4069 - val_accuracy: 0.5130
# Epoch 9/20
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.5096 - accuracy: 0.4666 - val_loss: 1.4041 - val_accuracy: 0.5030
# Epoch 10/20
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.5057 - accuracy: 0.4673 - val_loss: 1.3774 - val_accuracy: 0.5098
# Epoch 11/20
# 1563/1563 [==============================] - 21s 13ms/step - loss: 1.4890 - accuracy: 0.4757 - val_loss: 1.3703 - val_accuracy: 0.5203
# Epoch 12/20
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.4874 - accuracy: 0.4735 - val_loss: 1.3834 - val_accuracy: 0.5123
# Epoch 13/20
# 1563/1563 [==============================] - 24s 15ms/step - loss: 1.4769 - accuracy: 0.4791 - val_loss: 1.3778 - val_accuracy: 0.5161
# Epoch 14/20
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4699 - accuracy: 0.4764 - val_loss: 1.3589 - val_accuracy: 0.5278
# Epoch 15/20
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.4635 - accuracy: 0.4826 - val_loss: 1.3700 - val_accuracy: 0.5179
# Epoch 16/20
# 1563/1563 [==============================] - 34s 22ms/step - loss: 1.4600 - accuracy: 0.4838 - val_loss: 1.3477 - val_accuracy: 0.5278
# Epoch 17/20
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4555 - accuracy: 0.4861 - val_loss: 1.3453 - val_accuracy: 0.5228
# Epoch 18/20
# 1563/1563 [==============================] - 21s 13ms/step - loss: 1.4513 - accuracy: 0.4870 - val_loss: 1.3443 - val_accuracy: 0.5240
# Epoch 19/20
# 1563/1563 [==============================] - 21s 13ms/step - loss: 1.4428 - accuracy: 0.4905 - val_loss: 1.3467 - val_accuracy: 0.5286
# Epoch 20/20
# 1563/1563 [==============================] - 16s 10ms/step - loss: 1.4392 - accuracy: 0.4932 - val_loss: 1.3647 - val_accuracy: 0.5233

# %%
model = Sequential(
    [
    InputLayer((32,32, 3)),
    Conv2D(32,1, padding='same'),
    MaxPool2D(2, 2, padding='valid'),
    SpatialDropout2D(0.2),

    
    Conv2D(64,1, padding='same'),
    MaxPool2D(2, 2, padding='valid'),
    SpatialDropout2D(0.2),
    
    Conv2D(128,1, padding='same'),
    MaxPool2D(2, 2, padding='valid'),
    SpatialDropout2D(0.2),

        
    Conv2D(256,1, padding='same'),
    MaxPool2D(2, 2, padding='valid'),
    SpatialDropout2D(0.2),
    Flatten(),
    Dense(512, "relu"),
    Dropout(0.1),
    Dense(10, activation='softmax'),
        
        
    ]
        )
model.summary()
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=32
)


from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model = Sequential(
    [
    InputLayer((32,32, 3)),
    Conv2D(32,1, padding='same', activation='relu'),
    MaxPool2D(2, 2, padding='same'),
    SpatialDropout2D(0.2),

    
    Conv2D(64,1, padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),
    
    Conv2D(128,1, padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),

        
    Conv2D(256,1, padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),
    Flatten(),
    Dense(512, "relu"),
    Dropout(0.1),
    Dense(10, activation='softmax'),
        
        
    ]
        )
model.summary()
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=64
)


from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model = Sequential([
    InputLayer((32,32, 3)),
    Conv2D(32,  kernel_size=(5, 5), padding='same', activation='relu'),
    MaxPool2D(2, 2, padding='same'),
    SpatialDropout2D(0.2),
    
    Conv2D(64, kernel_size=(5, 5), padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),
    
    Conv2D(128,1, padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),

    Conv2D(256, kernel_size=(5, 5), padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),
    Flatten(),
    Dense(512, "relu"),
    Dropout(0.1),
    Dense(10, activation='softmax'),
    ])

model.summary()
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=128
)  


from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model = Sequential([
    InputLayer((32,32, 3)),
    Conv2D(32,  kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPool2D(2, 2, padding='same'),
    SpatialDropout2D(0.2),
    
    Conv2D(64, kernel_size=(7, 7), padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),
    
    Conv2D(128,1, padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),

    Conv2D(256, kernel_size=(9, 9), padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),
    Flatten(),
    Dense(512, "relu"),
    Dropout(0.1),
    Dense(10, activation='softmax'),
    ])

model.summary()
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=128
)  


from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model = Sequential([
    InputLayer((32,32, 3)),
    Conv2D(32,  kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPool2D(2, 2, padding='same'),
    SpatialDropout2D(0.2),
    
    Conv2D(64, kernel_size=(5, 5), padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),
    
    Conv2D(128, kernel_size=(7, 7),  padding='same', activation='relu'),
    MaxPool2D(3, 3),
    SpatialDropout2D(0.2),

    Conv2D(256, kernel_size=(9, 9), padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),
    Flatten(),
    Dense(512, "relu"),
    Dropout(0.1),
    Dense(10, activation='softmax'),
    ])

model.summary()
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=128
)  


from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model = Sequential([
    InputLayer((32,32, 3)),
    Conv2D(32,  kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPool2D(2, 2, padding='same'),
    # SpatialDropout2D(0.2),
    
    Conv2D(64, kernel_size=(5, 5), padding='same', activation='relu'),
    MaxPool2D(2, 2),
    # SpatialDropout2D(0.2),
    
    Conv2D(128, kernel_size=(7, 7),  padding='same', activation='relu'),
    MaxPool2D(3, 3),
    # SpatialDropout2D(0.2),

    Conv2D(256, kernel_size=(9, 9), padding='same', activation='relu'),
    MaxPool2D(2, 2),
    # SpatialDropout2D(0.2),
    
    Flatten(),
    Dense(512, "relu"),
    Dropout(0.1),
    Dense(10, activation='softmax'),
    ])

model.summary()
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=128
)  


from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model.evaluate(train_images, test_images)

# %%
from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model = Sequential([
    InputLayer((32,32, 3)),
    Conv2D(32,  kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPool2D(2, 2, padding='same'),
    SpatialDropout2D(0.2),
    
    Conv2D(64, kernel_size=(5, 5), padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),
    
    Conv2D(128, kernel_size=(7, 7),  padding='same', activation='relu'),
    MaxPool2D(3, 3),
    SpatialDropout2D(0.2),

    Conv2D(256, kernel_size=(9, 9), padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),
    
    Flatten(),
    Dense(512, "relu"),
    Dropout(0.1),
    Dense(10, activation='softmax'),
    ])

model.summary()
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=128
)  


from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# spatial_dropout2d (SpatialDr (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 64)        51264
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# spatial_dropout2d_1 (Spatial (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         401536
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# spatial_dropout2d_2 (Spatial (None, 2, 2, 128)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 2, 2, 256)         2654464
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# spatial_dropout2d_3 (Spatial (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 3,244,874
# Trainable params: 3,244,874
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 391/391 [==============================] - 9s 19ms/step - loss: 1.7437 - accuracy: 0.3471 - val_loss: 1.3424 - val_accuracy: 0.5107
# Epoch 2/20
# 391/391 [==============================] - 7s 17ms/step - loss: 1.3527 - accuracy: 0.5094 - val_loss: 1.1229 - val_accuracy: 0.5994
# Epoch 3/20
# 391/391 [==============================] - 8s 19ms/step - loss: 1.1847 - accuracy: 0.5780 - val_loss: 1.0297 - val_accuracy: 0.6347
# Epoch 4/20
patialDropout2D(0.2),
    
    Flatten(),
    Dense(512, "relu"),
    Dropout(0.1),
    Dense(10, activation='softmax'),
    ])

model.summary()
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=128
)  


from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model = Sequential([
    InputLayer((32,32, 3)),
    Conv2D(32,  kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPool2D(2, 2, padding='same'),
    # SpatialDropout2D(0.2),
    
    # Conv2D(64, kernel_size=(5, 5), padding='same', activation='relu'),
    # MaxPool2D(2, 2),
    # SpatialDropout2D(0.2),
    
    # Conv2D(128, kernel_size=(7, 7),  padding='same', activation='relu'),
    # MaxPool2D(3, 3),
    # SpatialDropout2D(0.2),

    # Conv2D(256, kernel_size=(9, 9), padding='same', activation='relu'),
    # MaxPool2D(2, 2),
    # SpatialDropout2D(0.2),
    
    Flatten(),
    Dense(512, "relu"),
    Dropout(0.1),
    Dense(10, activation='softmax'),
    ])

model.summary()
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=128
)  


from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Same Kernal with SpatialDropout

# %%
model = Sequential([
    InputLayer((32,32, 3)),
    Conv2D(32,  kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPool2D(2, 2, padding='same'),
    SpatialDropout2D(0.2),
    
    Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),
    
    # Conv2D(128, kernel_size=(7, 7),  padding='same', activation='relu'),
    # MaxPool2D(3, 3),
    # SpatialDropout2D(0.2),

    # Conv2D(256, kernel_size=(9, 9), padding='same', activation='relu'),
    # MaxPool2D(2, 2),
    # SpatialDropout2D(0.2),
    
    Flatten(),
    Dense(512, "relu"),
    Dropout(0.1),
    Dense(10, activation='softmax'),
    ])

model.summary()
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=128
)  


from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_22 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# spatial_dropout2d_15 (Spatia (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# spatial_dropout2d_16 (Spatia (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 512)               2097664
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 2,122,186
# Trainable params: 2,122,186
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 6s 13ms/step - loss: 1.5745 - accuracy: 0.4365 - val_loss: 1.2012 - val_accuracy: 0.5820
# Epoch 2/10
# 391/391 [==============================] - 6s 15ms/step - loss: 1.2035 - accuracy: 0.5767 - val_loss: 1.0509 - val_accuracy: 0.6321
# Epoch 3/10
# 391/391 [==============================] - 6s 15ms/step - loss: 1.0626 - accuracy: 0.6255 - val_loss: 0.9774 - val_accuracy: 0.6604
# Epoch 4/10
# 391/391 [==============================] - 8s 20ms/step - loss: 0.9581 - accuracy: 0.6642 - val_loss: 0.9125 - val_accuracy: 0.6823
# Epoch 5/10
# 391/391 [==============================] - 7s 17ms/step - loss: 0.8797 - accuracy: 0.6905 - val_loss: 0.9059 - val_accuracy: 0.6819
# Epoch 6/10
# 391/391 [==============================] - 7s 17ms/step - loss: 0.8070 - accuracy: 0.7183 - val_loss: 0.8629 - val_accuracy: 0.7012
# Epoch 7/10
# 391/391 [==============================] - 7s 17ms/step - loss: 0.7433 - accuracy: 0.7397 - val_loss: 0.8291 - val_accuracy: 0.7106
# Epoch 8/10
# 391/391 [==============================] - 10s 25ms/step - loss: 0.6757 - accuracy: 0.7615 - val_loss: 0.8108 - val_accuracy: 0.7182
# Epoch 9/10
# 391/391 [==============================] - 8s 20ms/step - loss: 0.6205 - accuracy: 0.7813 - val_loss: 0.8120 - val_accuracy: 0.7205
# Epoch 10/10
# 391/391 [==============================] - 8s 22ms/step - loss: 0.5619 - accuracy: 0.8029 - val_loss: 0.8027 - val_accuracy: 0.7252

# %%
from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model = Sequential([
    InputLayer((32,32, 3)),
    Conv2D(32,  kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPool2D(2, 2, padding='same'),
    SpatialDropout2D(0.2),
    
    Conv2D(64, kernel_size=(5, 5), padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),
    
    # Conv2D(128, kernel_size=(7, 7),  padding='same', activation='relu'),
    # MaxPool2D(3, 3),
    # SpatialDropout2D(0.2),

    # Conv2D(256, kernel_size=(9, 9), padding='same', activation='relu'),
    # MaxPool2D(2, 2),
    # SpatialDropout2D(0.2),
    
    Flatten(),
    Dense(512, "relu"),
    Dropout(0.1),
    Dense(10, activation='softmax'),
    ])

model.summary()
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=128
)  


from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# spatial_dropout2d_17 (Spatia (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 16, 16, 64)        51264
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# spatial_dropout2d_18 (Spatia (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 512)               2097664
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 2,154,954
# Trainable params: 2,154,954
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 15s 36ms/step - loss: 1.6184 - accuracy: 0.4192 - val_loss: 1.2306 - val_accuracy: 0.5641
# Epoch 2/10
# 391/391 [==============================] - 12s 31ms/step - loss: 1.2268 - accuracy: 0.5684 - val_loss: 1.0695 - val_accuracy: 0.6226
# Epoch 3/10
# 391/391 [==============================] - 12s 31ms/step - loss: 1.0794 - accuracy: 0.6227 - val_loss: 0.9753 - val_accuracy: 0.6618
# Epoch 4/10
10
# 391/391 [==============================] - 6s 16ms/step - loss: 0.7668 - accuracy: 0.7299 - val_loss: 0.7108 - val_accuracy: 0.7597

# %%
from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model = Sequential([
    InputLayer((32,32, 3)),
    Conv2D(32,  kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPool2D(8, 2, padding='same'),
    SpatialDropout2D(0.2),
    
    Conv2D(64, kernel_size=(4, 4), padding='same', activation='relu'),
    MaxPool2D(6, 2),
    SpatialDropout2D(0.2),
    
    Conv2D(128, kernel_size=(5, 5),  padding='same', activation='relu'),
    MaxPool2D(3, 2),
    SpatialDropout2D(0.2),

    Conv2D(256, kernel_size=(6, 6), padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),
    
    Flatten(),
    Dense(512, "relu"),
    Dropout(0.1),
    Dense(10, activation='softmax'),
    ])

model.summary()
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=128
)  


from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_71 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_71 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# spatial_dropout2d_71 (Spatia (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_72 (Conv2D)           (None, 16, 16, 64)        32832
# _________________________________________________________________
# max_pooling2d_72 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# spatial_dropout2d_72 (Spatia (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_73 (Conv2D)           (None, 6, 6, 128)         204928
# _________________________________________________________________
# max_pooling2d_73 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# spatial_dropout2d_73 (Spatia (None, 2, 2, 128)         0
# _________________________________________________________________
# conv2d_74 (Conv2D)           (None, 2, 2, 256)         1179904
# _________________________________________________________________
# max_pooling2d_74 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# spatial_dropout2d_74 (Spatia (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_36 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_37 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 1,555,274
# Trainable params: 1,555,274
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 7s 16ms/step - loss: 1.7958 - accuracy: 0.3203 - val_loss: 1.4015 - val_accuracy: 0.4939
# Epoch 2/10
# 391/391 [==============================] - 7s 18ms/step - loss: 1.4340 - accuracy: 0.4807 - val_loss: 1.2219 - val_accuracy: 0.5652
# Epoch 3/10
# 391/391 [==============================] - 7s 17ms/step - loss: 1.3098 - accuracy: 0.5319 - val_loss: 1.1269 - val_accuracy: 0.5977
# Epoch 4/10
# 164/391 [===========>..................] - ETA: 3s - loss: 1.2601 - accuracy: 0.5519

# %% [markdown]
# #### With Max pool size decrease

# %%
model = Sequential([
    InputLayer((32,32, 3)),
    Conv2D(32,  kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPool2D(8, 2, padding='same'),
    SpatialDropout2D(0.2),
    
    Conv2D(64, kernel_size=(4, 4), padding='same', activation='relu'),
    MaxPool2D(6, 2),
    SpatialDropout2D(0.2),
    
    Conv2D(128, kernel_size=(5, 5),  padding='same', activation='relu'),
    MaxPool2D(3, 2),
    SpatialDropout2D(0.2),

    Conv2D(256, kernel_size=(6, 6), padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),
    
    Flatten(),
    Dense(512, "relu"),
    Dropout(0.1),
    Dense(10, activation='softmax'),
    ])


model.summary()
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=128
)

from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_44 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_44 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# spatial_dropout2d_44 (Spatia (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 16, 16, 64)        32832
# _________________________________________________________________
# max_pooling2d_45 (MaxPooling (None, 7, 7, 64)          0
# _________________________________________________________________
# spatial_dropout2d_45 (Spatia (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 7, 7, 128)         204928
# _________________________________________________________________
# max_pooling2d_46 (MaxPooling (None, 3, 3, 128)         0
# _________________________________________________________________
# spatial_dropout2d_46 (Spatia (None, 3, 3, 128)         0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 3, 3, 256)         1179904
# _________________________________________________________________
# max_pooling2d_47 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# spatial_dropout2d_47 (Spatia (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 1,555,274
# Trainable params: 1,555,274
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 8s 18ms/step - loss: 1.7179 - accuracy: 0.3633 - val_loss: 1.2958 - val_accuracy: 0.5344
# Epoch 2/10
# 391/391 [==============================] - 8s 19ms/step - loss: 1.2983 - accuracy: 0.5370 - val_loss: 1.0606 - val_accuracy: 0.6301
# Epoch 3/10
# 391/391 [==============================] - 6s 16ms/step - loss: 1.1272 - accuracy: 0.6015 - val_loss: 0.9464 - val_accuracy: 0.6712
# Epoch 4/10
# 391/391 [==============================] - 6s 16ms/step - loss: 1.0327 - accuracy: 0.6366 - val_loss: 0.8709 - val_accuracy: 0.6936
# Epoch 5/10
# 391/391 [==============================] - 7s 19ms/step - loss: 0.9621 - accuracy: 0.6610 - val_loss: 0.8531 - val_accuracy: 0.7016
# Epoch 6/10
# 391/391 [==============================] - 7s 19ms/step - loss: 0.9099 - accuracy: 0.6819 - val_loss: 0.8221 - val_accuracy: 0.7114
# Epoch 7/10
# 391/391 [==============================] - 6s 16ms/step - loss: 0.8666 - accuracy: 0.6965 - val_loss: 0.8009 - val_accuracy: 0.7225
# Epoch 8/10
# 391/391 [==============================] - 7s 19ms/step - loss: 0.8273 - accuracy: 0.7097 - val_loss: 0.7431 - val_accuracy: 0.7432
# Epoch 9/10
# 391/391 [==============================] - 8s 20ms/step - loss: 0.7991 - accuracy: 0.7194 - val_loss: 0.7359 - val_accuracy: 0.7437
# Epoch 10/10
# 391/391 [==============================] - 6s 16ms/step - loss: 0.7668 - accuracy: 0.7299 - val_loss: 0.7108 - val_accuracy: 0.7597

# %%
from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model = Sequential([
    InputLayer((32,32, 3)),
    Conv2D(32,  kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPool2D(8, 2, padding='same'),
    SpatialDropout2D(0.2),
    
    Conv2D(64, kernel_size=(4, 4), padding='same', activation='relu'),
    MaxPool2D(6, 2),
    SpatialDropout2D(0.2),
    
    Conv2D(128, kernel_size=(5, 5),  padding='same', activation='relu'),
    MaxPool2D(3, 2),
    SpatialDropout2D(0.2),

    Conv2D(256, kernel_size=(6, 6), padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),
    
    Flatten(),
    Dense(512, "relu"),
    Dropout(0.1),
    Dense(256, "relu"),
    Dropout(0.1),
    Dense(10, activation='softmax'),
    ])

model.summary()
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=128
)  


from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_75 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_75 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# spatial_dropout2d_75 (Spatia (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_76 (Conv2D)           (None, 16, 16, 64)        32832
# _________________________________________________________________
# max_pooling2d_76 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# spatial_dropout2d_76 (Spatia (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_77 (Conv2D)           (None, 6, 6, 128)         204928
# _________________________________________________________________
# max_pooling2d_77 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# spatial_dropout2d_77 (Spatia (None, 2, 2, 128)         0
# _________________________________________________________________
# conv2d_78 (Conv2D)           (None, 2, 2, 256)         1179904
# _________________________________________________________________
# max_pooling2d_78 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# spatial_dropout2d_78 (Spatia (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_19 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_39 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_40 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 1,684,042
# Trainable params: 1,684,042
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 5s 11ms/step - loss: 1.8845 - accuracy: 0.2738 - val_loss: 1.5278 - val_accuracy: 0.4172
# Epoch 2/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.5576 - accuracy: 0.4226 - val_loss: 1.3805 - val_accuracy: 0.4902
# Epoch 3/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.4374 - accuracy: 0.4773 - val_loss: 1.2618 - val_accuracy: 0.5480
# Epoch 4/10
# 391/391 [==============================] - 6s 14ms/step - loss: 1.3552 - accuracy: 0.5140 - val_loss: 1.1690 - val_accuracy: 0.5840
# Epoch 5/10
# 391/391 [==============================] - 6s 14ms/step - loss: 1.2980 - accuracy: 0.5359 - val_loss: 1.1400 - val_accuracy: 0.5909
# Epoch 6/10
# 391/391 [==============================] - 6s 15ms/step - loss: 1.2497 - accuracy: 0.5566 - val_loss: 1.0980 - val_accuracy: 0.6103
# Epoch 7/10
# 391/391 [==============================] - 6s 16ms/step - loss: 1.2098 - accuracy: 0.5707 - val_loss: 1.0799 - val_accuracy: 0.6168
# Epoch 8/10
# 391/391 [==============================] - 6s 15ms/step - loss: 1.1838 - accuracy: 0.5802 - val_loss: 1.0065 - val_accuracy: 0.6510
# Epoch 9/10
# 391/391 [==============================] - 6s 14ms/step - loss: 1.1507 - accuracy: 0.5919 - val_loss: 1.0038 - val_accuracy: 0.6465
# Epoch 10/10
# 391/391 [==============================] - 6s 16ms/step - loss: 1.1296 - accuracy: 0.6025 - val_loss: 0.9815 - val_accuracy: 0.6580

# %% [markdown]
# ### Adding fully connected layers

# %%
model = Sequential([
    InputLayer((32,32, 3)),
    Conv2D(32,  kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPool2D(8, 2, padding='same'),
    SpatialDropout2D(0.2),
    
    Conv2D(64, kernel_size=(4, 4), padding='same', activation='relu'),
    MaxPool2D(6, 2),
    SpatialDropout2D(0.2),
    
    Conv2D(128, kernel_size=(5, 5),  padding='same', activation='relu'),
    MaxPool2D(3, 2),
    SpatialDropout2D(0.2),

    Conv2D(256, kernel_size=(6, 6), padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),
    
    Flatten(),
    Dense(512, "relu"),
    Dropout(0.1),
    Dense(256, "relu"),
    Dropout(0.1),
    Dense(10, activation='softmax'),
    ])


model.summary()
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=128
)

from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_91 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_91 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# spatial_dropout2d_91 (Spatia (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_92 (Conv2D)           (None, 16, 16, 64)        32832
# _________________________________________________________________
# max_pooling2d_92 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# spatial_dropout2d_92 (Spatia (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_93 (Conv2D)           (None, 6, 6, 128)         204928
# _________________________________________________________________
# max_pooling2d_93 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# spatial_dropout2d_93 (Spatia (None, 2, 2, 128)         0
# _________________________________________________________________
# conv2d_94 (Conv2D)           (None, 2, 2, 256)         1179904
# _________________________________________________________________
# max_pooling2d_94 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# spatial_dropout2d_94 (Spatia (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_23 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_51 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_52 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_53 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 1,684,042
# Trainable params: 1,684,042
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 8s 17ms/step - loss: 1.8551 - accuracy: 0.2850 - val_loss: 1.5253 - val_accuracy: 0.4286
# Epoch 2/10
# 391/391 [==============================] - 6s 16ms/step - loss: 1.5409 - accuracy: 0.4345 - val_loss: 1.3314 - val_accuracy: 0.5152
# Epoch 3/10
# 391/391 [==============================] - 7s 18ms/step - loss: 1.4120 - accuracy: 0.4905 - val_loss: 1.2835 - val_accuracy: 0.5360
# Epoch 4/10
# 391/391 [==============================] - 6s 16ms/step - loss: 1.3361 - accuracy: 0.5218 - val_loss: 1.1516 - val_accuracy: 0.5892
# Epoch 5/10
# 391/391 [==============================] - 8s 21ms/step - loss: 1.2729 - accuracy: 0.5443 - val_loss: 1.1230 - val_accuracy: 0.5963
# Epoch 6/10
# 391/391 [==============================] - 9s 22ms/step - loss: 1.2258 - accuracy: 0.5642 - val_loss: 1.0773 - val_accuracy: 0.6208
# Epoch 7/10
# 391/391 [==============================] - 9s 23ms/step - loss: 1.1860 - accuracy: 0.5809 - val_loss: 1.0495 - val_accuracy: 0.6294
# Epoch 8/10
# 391/391 [==============================] - 9s 22ms/step - loss: 1.1518 - accuracy: 0.5929 - val_loss: 0.9977 - val_accuracy: 0.6446
# Epoch 9/10
# 391/391 [==============================] - 9s 23ms/step - loss: 1.1332 - accuracy: 0.6017 - val_loss: 0.9820 - val_accuracy: 0.6536
# Epoch 10/10
# 391/391 [==============================] - 9s 22ms/step - loss: 1.1031 - accuracy: 0.6112 - val_loss: 0.9742 - val_accuracy: 0.6598

# %%
from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model = Sequential([
    InputLayer((32,32, 3)),
    Conv2D(32,  kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPool2D(8, 2, padding='same'),
    SpatialDropout2D(0.2),
    
    Conv2D(64, kernel_size=(4, 4), padding='same', activation='relu'),
    MaxPool2D(6, 2),
    SpatialDropout2D(0.2),
    
    Conv2D(128, kernel_size=(5, 5),  padding='same', activation='relu'),
    MaxPool2D(3, 2),
    SpatialDropout2D(0.2),

    Conv2D(256, kernel_size=(6, 6), padding='same', activation='relu'),
    MaxPool2D(2, 2),
    SpatialDropout2D(0.2),
    
    Flatten(),
    Dense(512, "relu"),
    Dropout(0.1),
    Dense(256, "relu"),
    Dropout(0.1),
    
    Dense(128, "relu"),
    Dropout(0.1),
    Dense(10, activation='softmax'),
    ])

model.summary()
optimizer = Adam()
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    x=train_images, 
    y=train_labels, 
    validation_data=(test_images, test_labels), 
    epochs=10, 
    batch_size=128
)  


from matplotlib import pyplot as plt
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_83 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_83 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# spatial_dropout2d_83 (Spatia (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_84 (Conv2D)           (None, 16, 16, 64)        32832
# _________________________________________________________________
# max_pooling2d_84 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# spatial_dropout2d_84 (Spatia (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_85 (Conv2D)           (None, 6, 6, 128)         204928
# _________________________________________________________________
# max_pooling2d_85 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# spatial_dropout2d_85 (Spatia (None, 2, 2, 128)         0
# _________________________________________________________________
# conv2d_86 (Conv2D)           (None, 2, 2, 256)         1179904
# _________________________________________________________________
# max_pooling2d_86 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# spatial_dropout2d_86 (Spatia (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_44 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_45 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_46 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_47 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 1,715,658
# Trainable params: 1,715,658
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 6s 13ms/step - loss: 1.8762 - accuracy: 0.2776 - val_loss: 1.5644 - val_accuracy: 0.4074
# Epoch 2/10
# 391/391 [==============================] - 7s 17ms/step - loss: 1.5765 - accuracy: 0.4175 - val_loss: 1.3457 - val_accuracy: 0.5142
# Epoch 3/10
# 391/391 [==============================] - 6s 14ms/step - loss: 1.4405 - accuracy: 0.4788 - val_loss: 1.2500 - val_accuracy: 0.5455
# Epoch 4/10
# 391/391 [==============================] - 6s 14ms/step - loss: 1.3580 - accuracy: 0.5158 - val_loss: 1.1658 - val_accuracy: 0.5823
# Epoch 5/10
# 391/391 [==============================] - 6s 15ms/step - loss: 1.2957 - accuracy: 0.5382 - val_loss: 1.1274 - val_accuracy: 0.5985
# Epoch 6/10
# 391/391 [==============================] - 7s 17ms/step - loss: 1.2564 - accuracy: 0.5554 - val_loss: 1.1010 - val_accuracy: 0.6099
# Epoch 7/10
# 391/391 [==============================] - 7s 18ms/step - loss: 1.2228 - accuracy: 0.5666 - val_loss: 1.0941 - val_accuracy: 0.6120
# Epoch 8/10
# 391/391 [==============================] - 8s 19ms/step - loss: 1.1827 - accuracy: 0.5827 - val_loss: 1.0451 - val_accuracy: 0.6368
# Epoch 9/10
# 391/391 [==============================] - 8s 21ms/step - loss: 1.1599 - accuracy: 0.5949 - val_loss: 1.0081 - val_accuracy: 0.6541
# Epoch 10/10
# 391/391 [==============================] - 8s 19ms/step - loss: 1.1354 - accuracy: 0.6028 - val_loss: 0.9999 - val_accuracy: 0.6493
