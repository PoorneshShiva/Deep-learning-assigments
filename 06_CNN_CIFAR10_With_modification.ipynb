# %% [markdown]
# <a href="https://colab.research.google.com/github/PoorneshShiva/Deep-learning-assigments/blob/main/06_CNN_CIFAR10_With_modification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task: CIFAR-10 classification
#
# The [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html)
#
# > "consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#
# >The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class."
#
# <img src="http://drive.google.com/uc?export=view&id=1wlfkvZgS0oBDwxKicWmYgtsJmP3IcMdj">

# %% [markdown]
# # Preliminaries

# %%
import numpy as np
import os

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, Conv2D, MaxPool2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adadelta, Adam, SGD
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.regularizers import l1
from tensorflow.keras.backend import clear_session
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.initializers import glorot_normal

# Fix seeds for (hopefully) reproducible results
from numpy.random import seed
seed(14)
tf.random.set_seed(19)

# %% [markdown]
# Download the data if necessary and load it:

# %%
train, test = tf.keras.datasets.cifar10.load_data()

# %%
train, test = tf.keras.datasets.cifar10.load_data()

# TODO: Split the images into different sets and normalise them
train_images = train[0]  / 255.
train_labels = train[1]
test_images = test[0]  / 255.
test_labels = test[1]

print(train_images.shape, test_images.shape)
print(train_labels.shape, test_labels.shape)
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# (50000, 1) (10000, 1)

# %% [markdown]
# ### Categories:
#
# - airplane
# - automobile
# - bird
# - cat
# - deer
# - dog
# - frog
# - horse
# - ship
# - truck

# %%
# TODO: Fill in the classes
classes = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

# %%
# TODO: Plot some of the images along with their labels
from matplotlib import pyplot as plt
from math import ceil

def show_images(images, labels):
    """Show images in a grid
    """
    n_rows = ceil(len(images) / 10)
    plt.figure(figsize=(20, 8))
    for i, image in enumerate(images):
        ax = plt.subplot(n_rows, 10, i + 1, xticks=[], yticks=[])
        # below we scale the pixel intensities back to display the images correctly
        plt.imshow(image, cmap='Greys')
        plt.title(classes[labels[i][0]])

show_images(train_images[:30], train_labels[:30])
plt.show();

# %% [markdown]
# # Model
#
# ## Parameters

# %%
# TASK - Hyperparameters
# Fill in the initial values!
# Later, experiment!
#############################


# dropout - Something between 0.0 < dropout_rate < 1.0, think in "tens of percentages" as default
# dropout rate for conv layers
dropout_rate_1 = 0.5
# dropout rate for fully connected layers
dropout_rate_2 = 0.5

# Choose an appropriate batch size for the training!
batch_size = 128

# Choose an appropriate number of epochs
epoch_count = 100

# These are the default parameters, you can experiment with learning rates, schedules, ...

# %% [markdown]
# ## Network

# %%
# adapted from https://github.com/jtopor/CUNY-MSDA-661/blob/master/CIFAR-CNN/TF-Layers-CIFAR-GITHUB-v3.py


tf.compat.v1.reset_default_graph() # It's good practice to clean and reset everything
clear_session()          # even using Keras


# WE USE FUNCTIONAL API!
# (Could be different, but not now...)



# Model
#######

# Define the input!
# Remember, we have pictures with 32x32 pixels and 3 color channels
# Disregard batch size, Keras will do that for us.
x = input_tensor = Input(shape=(32, 32, 3))

# Convolutional Layer #1: (batch_size, 32, 32, 3) -> (batch_size, 32, 32, 64)
# Define a "normal" convolutional layer for images (not a single sequence, so ?D)
# There should be 64 convolutional units
# The kernel should be 5 in width and heigth
# There should be padding so that the input and output dimensions would be equivalent
# The non-linearity should be ReLU
conv1 = Conv2D(filters=64, kernel_size=(5, 5), padding='same', activation='relu')(x)

# Pooling Layer #1: (batch_size, 32, 32, 64) -> (batch_size, 16, 16, 64)
# Define a maximum based pooling layer with appropriate dimensions
# The pooling size should be 2,2 and stride 2
pool1 = MaxPool2D(pool_size=(2, 2), strides=2)(conv1)

# Define a dropout layer with using the first dropout rate parameter
dropout1 = Dropout(dropout_rate_1)(pool1)

# Convolutional Layer #2: (batch_size, 16, 16, 64) -> (batch_size, 16, 16, 64)
# Repeat the prior conv layer
# Watch for the right input
conv2 = Conv2D(filters=64, kernel_size=(5, 5), padding='same', activation='relu')(dropout1)

# Pooling Layer #2: (batch_size, 16, 16, 64) -> (batch_size, 8, 8, 64)
# Repeat the prior pooling layer
# Watch for the right input
pool2 = MaxPool2D(pool_size=(2, 2), strides=2)(conv2)

# Define a dropout layer with using the FIRST dropout rate parameter
dropout2 = Dropout(dropout_rate_2)(pool2)

# Convert tensors into vectors: (batch_size, 8, 8, 64) -> (batch_size, 4096)
# Use a single KERAS function, NO numpy or reshape magic!
# Hint: the result is not 2D but "flat"
pool2_flat = Flatten()(dropout2)

# Fully connected Layer #1: (batch_size, 4096)-> (batch_size, 512)
# Define a fully connected layer with 512 nodes and ReLU
dense1 = Dense(512, activation='relu')(pool2_flat)

# Define a dropout layer with using the SECOND dropout rate parameter
dropout3 = Dropout(dropout_rate_2)(dense1)

# Dense Layer #1: (batch_size, 512)-> (batch_size, 256)
# Define a fully connected layer with 256 nodes and ReLU
dense2 = Dense(256, activation='relu')(dropout3)

# Define a dropout layer with using the SECOND dropout rate parameter
dropout4 = Dropout(dropout_rate_2)(dense2)

# Logits layer: (batch_size, 256) -> (batch_size, 10)
# Define a fully connected layer with ??? nodes
# Think about it, what shape should the output be?
# What activation?
# Think about it: we are in a classification problem!
predictions = Dense(10, activation='softmax')(dropout4)

# Full model
# Instantiate (initialize) the model with inputs and outputs
model = Model(inputs=x, outputs=predictions)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 32, 32, 64)          │           4,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 16, 16, 64)          │         102,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       2,097,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,338,890 (8.92 MB)
#  Trainable params: 2,338,890 (8.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Loss, optimization and compilation

# %%
# Loss
loss = sparse_categorical_crossentropy # we use this cross entropy variant as the input is not
                                       # one-hot encoded

# Optimizer
# Choose an optimizer - adaptive ones work well here
optimizer = Adam()

# Compilation
#############
model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

# %% [markdown]
# ## Training

# %%
train_labels
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
history = model.fit(x=train_images, y=train_labels,
                    validation_data=(test_images, test_labels),
                    epochs=epoch_count,
                    batch_size=batch_size)
# Out:
# Epoch 1/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.2408 - loss: 2.0189 - val_accuracy: 0.4729 - val_loss: 1.4455
# Epoch 2/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.4580 - loss: 1.4892 - val_accuracy: 0.5401 - val_loss: 1.2724
# Epoch 3/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.5180 - loss: 1.3458 - val_accuracy: 0.5903 - val_loss: 1.1694
# Epoch 4/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.5526 - loss: 1.2540 - val_accuracy: 0.6138 - val_loss: 1.1029
# Epoch 5/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.5823 - loss: 1.1787 - val_accuracy: 0.6445 - val_loss: 1.0197
# Epoch 6/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.6047 - loss: 1.1346 - val_accuracy: 0.6574 - val_loss: 0.9756
# Epoch 7/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.6238 - loss: 1.0784 - val_accuracy: 0.6637 - val_loss: 0.9563
# Epoch 8/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.6390 - loss: 1.0330 - val_accuracy: 0.6872 - val_loss: 0.9138
# Epoch 9/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.6459 - loss: 1.0133 - val_accuracy: 0.6802 - val_loss: 0.9270
# Epoch 10/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.6629 - loss: 0.9747 - val_accuracy: 0.6928 - val_loss: 0.8912
# Epoch 11/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.6709 - loss: 0.9521 - val_accuracy: 0.7086 - val_loss: 0.8448
# Epoch 12/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.6766 - loss: 0.9281 - val_accuracy: 0.6998 - val_loss: 0.8619
# Epoch 13/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.6846 - loss: 0.9078 - val_accuracy: 0.7197 - val_loss: 0.8243
# Epoch 14/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.6946 - loss: 0.8844 - val_accuracy: 0.7080 - val_loss: 0.8577
# Epoch 15/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.6938 - loss: 0.8798 - val_accuracy: 0.7083 - val_loss: 0.8321
# Epoch 16/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.7012 - loss: 0.8649 - val_accuracy: 0.7218 - val_loss: 0.8098
# Epoch 17/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.7061 - loss: 0.8495 - val_accuracy: 0.7312 - val_loss: 0.7790
# Epoch 18/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.7098 - loss: 0.8373 - val_accuracy: 0.7330 - val_loss: 0.7870
# Epoch 19/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.7141 - loss: 0.8224 - val_accuracy: 0.7289 - val_loss: 0.7814
# Epoch 20/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.7193 - loss: 0.8122 - val_accuracy: 0.7388 - val_loss: 0.7623
# Epoch 21/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.7218 - loss: 0.8020 - val_accuracy: 0.7339 - val_loss: 0.7640
# Epoch 22/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.7260 - loss: 0.7878 - val_accuracy: 0.7458 - val_loss: 0.7646
# Epoch 23/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.7321 - loss: 0.7743 - val_accuracy: 0.7322 - val_loss: 0.7773
# Epoch 24/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.7343 - loss: 0.7638 - val_accuracy: 0.7293 - val_loss: 0.7802
# Epoch 25/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.7410 - loss: 0.7450 - val_accuracy: 0.7443 - val_loss: 0.7588
# Epoch 26/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.7390 - loss: 0.7533 - val_accuracy: 0.7445 - val_loss: 0.7528
# Epoch 27/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.7472 - loss: 0.7365 - val_accuracy: 0.7548 - val_loss: 0.7422
# Epoch 28/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.7446 - loss: 0.7332 - val_accuracy: 0.7465 - val_loss: 0.7550
# Epoch 29/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.7481 - loss: 0.7241 - val_accuracy: 0.7473 - val_loss: 0.7631
# Epoch 30/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.7524 - loss: 0.7127 - val_accuracy: 0.7446 - val_loss: 0.7498
# Epoch 31/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.7580 - loss: 0.7057 - val_accuracy: 0.7552 - val_loss: 0.7176
# Epoch 32/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.7595 - loss: 0.6975 - val_accuracy: 0.7478 - val_loss: 0.7349
# Epoch 33/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.7607 - loss: 0.6982 - val_accuracy: 0.7614 - val_loss: 0.7100
# Epoch 34/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.7655 - loss: 0.6732 - val_accuracy: 0.7565 - val_loss: 0.7291
# Epoch 35/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.7669 - loss: 0.6764 - val_accuracy: 0.7538 - val_loss: 0.7246
# Epoch 36/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.7636 - loss: 0.6779 - val_accuracy: 0.7517 - val_loss: 0.7228
# Epoch 37/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.7715 - loss: 0.6659 - val_accuracy: 0.7585 - val_loss: 0.7088
# Epoch 38/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.7732 - loss: 0.6542 - val_accuracy: 0.7633 - val_loss: 0.7085
# Epoch 39/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.7734 - loss: 0.6527 - val_accuracy: 0.7473 - val_loss: 0.7527
# Epoch 40/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.7769 - loss: 0.6461 - val_accuracy: 0.7624 - val_loss: 0.7158
# Epoch 41/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.7759 - loss: 0.6382 - val_accuracy: 0.7584 - val_loss: 0.7286
# Epoch 42/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.7864 - loss: 0.6366 - val_accuracy: 0.7603 - val_loss: 0.7092
# Epoch 43/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.7828 - loss: 0.6239 - val_accuracy: 0.7575 - val_loss: 0.7168
# Epoch 44/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.7788 - loss: 0.6318 - val_accuracy: 0.7696 - val_loss: 0.6855
# Epoch 45/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.7842 - loss: 0.6247 - val_accuracy: 0.7565 - val_loss: 0.7179
# Epoch 46/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.7889 - loss: 0.6202 - val_accuracy: 0.7649 - val_loss: 0.7124
# Epoch 47/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.7916 - loss: 0.6042 - val_accuracy: 0.7620 - val_loss: 0.7097
# Epoch 48/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.7964 - loss: 0.5978 - val_accuracy: 0.7763 - val_loss: 0.6813
# Epoch 49/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.7936 - loss: 0.6024 - val_accuracy: 0.7748 - val_loss: 0.6772
# Epoch 50/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.7954 - loss: 0.5853 - val_accuracy: 0.7561 - val_loss: 0.7219
# Epoch 51/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.7974 - loss: 0.5941 - val_accuracy: 0.7589 - val_loss: 0.7105
# Epoch 52/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8012 - loss: 0.5882 - val_accuracy: 0.7726 - val_loss: 0.6861
# Epoch 53/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.8058 - loss: 0.5648 - val_accuracy: 0.7703 - val_loss: 0.6833
# Epoch 54/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8055 - loss: 0.5622 - val_accuracy: 0.7728 - val_loss: 0.6762
# Epoch 55/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8063 - loss: 0.5723 - val_accuracy: 0.7727 - val_loss: 0.6767
# Epoch 56/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8101 - loss: 0.5602 - val_accuracy: 0.7705 - val_loss: 0.6746
# Epoch 57/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8060 - loss: 0.5691 - val_accuracy: 0.7646 - val_loss: 0.6917
# Epoch 58/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8094 - loss: 0.5592 - val_accuracy: 0.7657 - val_loss: 0.6837
# Epoch 59/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8098 - loss: 0.5573 - val_accuracy: 0.7677 - val_loss: 0.6810
# Epoch 60/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8140 - loss: 0.5457 - val_accuracy: 0.7669 - val_loss: 0.6841
# Epoch 61/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8169 - loss: 0.5415 - val_accuracy: 0.7740 - val_loss: 0.6820
# Epoch 62/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8132 - loss: 0.5480 - val_accuracy: 0.7657 - val_loss: 0.7036
# Epoch 63/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.8156 - loss: 0.5428 - val_accuracy: 0.7712 - val_loss: 0.6776
# Epoch 64/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8164 - loss: 0.5386 - val_accuracy: 0.7712 - val_loss: 0.6775
# Epoch 65/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8161 - loss: 0.5407 - val_accuracy: 0.7777 - val_loss: 0.6652
# Epoch 66/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.8249 - loss: 0.5199 - val_accuracy: 0.7686 - val_loss: 0.7003
# Epoch 67/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.8220 - loss: 0.5229 - val_accuracy: 0.7695 - val_loss: 0.6919
# Epoch 68/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8201 - loss: 0.5348 - val_accuracy: 0.7752 - val_loss: 0.6748
# Epoch 69/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8224 - loss: 0.5234 - val_accuracy: 0.7762 - val_loss: 0.6786
# Epoch 70/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8254 - loss: 0.5138 - val_accuracy: 0.7629 - val_loss: 0.6973
# Epoch 71/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8266 - loss: 0.5208 - val_accuracy: 0.7777 - val_loss: 0.6731
# Epoch 72/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8329 - loss: 0.4944 - val_accuracy: 0.7771 - val_loss: 0.6697
# Epoch 73/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8305 - loss: 0.5071 - val_accuracy: 0.7769 - val_loss: 0.6750
# Epoch 74/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8315 - loss: 0.5028 - val_accuracy: 0.7740 - val_loss: 0.6843
# Epoch 75/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8264 - loss: 0.5129 - val_accuracy: 0.7802 - val_loss: 0.6646
# Epoch 76/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8325 - loss: 0.4954 - val_accuracy: 0.7784 - val_loss: 0.6703
# Epoch 77/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.8356 - loss: 0.4920 - val_accuracy: 0.7801 - val_loss: 0.6669
# Epoch 78/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8338 - loss: 0.4978 - val_accuracy: 0.7788 - val_loss: 0.6716
# Epoch 79/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8343 - loss: 0.4935 - val_accuracy: 0.7810 - val_loss: 0.6703
# Epoch 80/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8360 - loss: 0.4898 - val_accuracy: 0.7757 - val_loss: 0.6770
# Epoch 81/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8389 - loss: 0.4758 - val_accuracy: 0.7752 - val_loss: 0.6796
# Epoch 82/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8395 - loss: 0.4861 - val_accuracy: 0.7771 - val_loss: 0.6739
# Epoch 83/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.8365 - loss: 0.4843 - val_accuracy: 0.7774 - val_loss: 0.6868
# Epoch 84/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8398 - loss: 0.4850 - val_accuracy: 0.7801 - val_loss: 0.6795
# Epoch 85/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8398 - loss: 0.4765 - val_accuracy: 0.7766 - val_loss: 0.6810
# Epoch 86/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8412 - loss: 0.4712 - val_accuracy: 0.7684 - val_loss: 0.7056
# Epoch 87/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8372 - loss: 0.4859 - val_accuracy: 0.7805 - val_loss: 0.6820
# Epoch 88/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8391 - loss: 0.4837 - val_accuracy: 0.7781 - val_loss: 0.6806
# Epoch 89/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.8417 - loss: 0.4729 - val_accuracy: 0.7788 - val_loss: 0.6713
# Epoch 90/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8443 - loss: 0.4633 - val_accuracy: 0.7789 - val_loss: 0.6774
# Epoch 91/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8459 - loss: 0.4558 - val_accuracy: 0.7808 - val_loss: 0.6723
# Epoch 92/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8495 - loss: 0.4495 - val_accuracy: 0.7785 - val_loss: 0.6664
# Epoch 93/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8470 - loss: 0.4571 - val_accuracy: 0.7804 - val_loss: 0.6785
# Epoch 94/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.8449 - loss: 0.4683 - val_accuracy: 0.7791 - val_loss: 0.6765
# Epoch 95/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8477 - loss: 0.4583 - val_accuracy: 0.7817 - val_loss: 0.6741
# Epoch 96/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8498 - loss: 0.4524 - val_accuracy: 0.7801 - val_loss: 0.6727
# Epoch 97/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8432 - loss: 0.4598 - val_accuracy: 0.7816 - val_loss: 0.6739
# Epoch 98/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8484 - loss: 0.4496 - val_accuracy: 0.7847 - val_loss: 0.6643
# Epoch 99/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.8483 - loss: 0.4553 - val_accuracy: 0.7810 - val_loss: 0.6746
# Epoch 100/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8534 - loss: 0.4400 - val_accuracy: 0.7827 - val_loss: 0.6754

# %%
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# TODO: Plot loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
assert max(history.history['val_accuracy']) > 0.75

# %% [markdown]
# ## Visualization

# %%
# TODO: Plot Confusion Matrix
...

# %%
# TODO: Plot Classification Report
...
